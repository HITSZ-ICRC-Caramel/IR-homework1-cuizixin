# %%
from utils import search

# %%
query = "金融&债券-高盛-公告"
search(query)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/x5/cz035yvn1lx08dx1bgv55q1w0000gn/T/jieba.cache
# Loading model cost 0.921 seconds.
# Prefix dict has been built succesfully.
# 搜索结果：
# 搜索到满足条件的文档数1606。
# document16387:
# ...

# %% [markdown]
# ## 测试

# %%
# query = "金融&债券-高盛"
# exps, words_query = parse_query(query)
# print(exps)
# print(words_query)

# %%
# check_syntax(''.join(exps), variables=[set() for i in range(len(exps))])

# %%
# ids = eval_exps(''.join(exps), words_query, word2docs)

# %%
# ids

# %%
# show(ids,10,raw_docs)
